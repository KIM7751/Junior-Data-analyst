# %% [markdown]
# # 결정 트리
# - 분류와 회귀에 사용되는 지도 학습 방법
# - 데이터 특성으로 부터 추론된 결정 규칙을 통해 값을 예측
# - if_then_else 결정 규칙을 통해 데이터 학습
# - 트리의 깊이가 깊을수록 복잡한 모델
# - 결정 트리 장점
#     - 이해와 해석이 쉬움
#     - 시각화가 용이
#     - 많은 데이터 전처리 필요 X
#     - 수치형 범주형 데이터 모두 이용 가능

# %%
import pandas as pd
import numpy as np
import graphviz    # 트리를 그리기 위해서
import multiprocessing
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid'])

# %%
from sklearn.datasets import load_iris, load_wine, load_breast_cancer
from sklearn.datasets import load_boston, load_diabetes
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %% [markdown]
# # 분류를 위한 데이터

# %% [markdown]
# ## 붓꽃 데이터

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(data = iris.data, columns = iris.feature_names)
iris_df['target'] = iris.target
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %% [markdown]
# ## 와인 데이터

# %%
wine = load_wine()

# %%
wine_df = pd.DataFrame(data = wine.data, columns = wine.feature_names)
wine_df['target'] = wine.target
wine_df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
cancer = load_breast_cancer()

# %%
cancer_df = pd.DataFrame(data = cancer.data, columns = cancer.feature_names)
cancer_df['target'] = cancer.target
cancer_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# # 회귀를 위한 데이터

# %% [markdown]
# ## 보스턴 주택 가격 데이터

# %%
boston = load_boston()

# %%
boston_df = pd.DataFrame(data = boston.data, columns = boston.feature_names)
boston_df['target'] = boston.target
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %% [markdown]
# ## 당뇨병 데이터

# %%
diabetes = load_diabetes()

# %%
diabetes_df = pd.DataFrame(data = diabetes.data, columns = diabetes.feature_names)
diabetes_df['target'] = diabetes.target
diabetes_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %% [markdown]
# # 분류 - DecisionTreeClassifier()
# - X는 [n_samples, n_features] 크기의 데이터 특성 배열
# - y는 [n_samples] 크기의 정답 배열

# %%
X = [[0, 0], [1, 1]]  # X에 대해서 0,0 일땐 0  / 1,1일땐 1
y = [0, 1]            # 정답 배열

model = tree.DecisionTreeClassifier()
model = model.fit(X, y)

# %%
model.predict([[2., 2.]]) # 2, 2 이라는 숫자를 줬을 때 결론적으로 1 이라는 클래스를 반환
# Out:
# array([1])

# %%
model.predict_proba([[2., 2.]]) # proba 확률을 반환해주는데 확률적으로 어디에 가까운지 = 1 쪽에 가깞다
# Out:
# array([[0., 1.]])

# %% [markdown]
# ## 붓꽃 데이터 학습

# %% [markdown]
# ### 전처리 없이 학습
# - 결정 트리는 규칙을 학습하기 때문에 전처리에 큰 영향을 받지 않는다

# %%
model = DecisionTreeClassifier()

# %%
cross_val_score(
    estimator = model,
    X = iris.data, y = iris.target,
    cv = 5,
    n_jobs = multiprocessing.cpu_count()
)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 1.        , 1.        ])

# %% [markdown]
# ### 전처리 후 학습

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeClassifier()
)

# %%
cross_val_score(
    estimator = model,
    X = iris.data, y = iris.target,
    cv = 5,
    n_jobs = multiprocessing.cpu_count()
)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.96666667, 1.        ])

# %% [markdown]
# ## 학습된 결정 트리 시각화

# %%
model = DecisionTreeClassifier()
model.fit(iris.data, iris.target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### 텍스트를 통한 시각화

# %%
r = tree.export_text(decision_tree = model,
                     feature_names = iris.feature_names)
print(r)
# Out:
# |--- petal width (cm) <= 0.80
# |   |--- class: 0
# |--- petal width (cm) >  0.80
# |   |--- petal width (cm) <= 1.75
# |   |   |--- petal length (cm) <= 4.95
# |   |   |   |--- petal width (cm) <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- petal width (cm) >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- petal length (cm) >  4.95
# |   |   |   |--- petal width (cm) <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- petal width (cm) >  1.55
# |   |   |   |   |--- petal length (cm) <= 5.45
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- petal length (cm) >  5.45
# |   |   |   |   |   |--- class: 2
# |   |--- petal width (cm) >  1.75
# |   |   |--- petal length (cm) <= 4.85
# |   |   |   |--- sepal width (cm) <= 3.10
# |   |   |   |   |--- class: 2
# |   |   |   |--- sepal width (cm) >  3.10
# |   |   |   |   |--- class: 1
# |   |   |--- petal length (cm) >  4.85
# |   |   |   |--- class: 2

# %% [markdown]
# ### plot_tree를 사용한 시각화

# %%
tree.plot_tree(model);

# %% [markdown]
# ### graphviz를 사용한 시각화

# %%
dot_data = tree.export_graphviz (decision_tree = model,
                                feature_names = iris.feature_names,
                                class_names = iris.target_names,
                                filled = True, rounded = True,  # 색 채우기, 둥글게, 특수 문자 허용
                                special_characters = True)

graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ### 결정 경계 시각화

# %%
n_classes = 3
plot_colors = 'ryb'
plot_step = 0.02

# %%
plt.figure(figsize = (16, 8))

for pairidx, pair in enumerate([[0, 1],[0, 2], [0, 3],
                                [1, 2], [1, 3], [2, 3]]):
    X = iris.data[:, pair]
    y = iris.target
    
    model = DecisionTreeClassifier()
    model = model.fit(X, y)
    
    plt.subplot(2, 3, pairidx + 1) # 결정 경계 시각화를 위해 작성 / 서브 플롯마다 어떤 경계를 나타내는지가 결국 트리 형성의 기준이 됨
    
    x_min, x_max = X[:, 0].min()-1, X[:, 0].max()+1
    y_min, y_max = X[:, 1].min()-1, X[:, 1].max()+1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                         np.arange(y_min, y_max, plot_step))
    
    plt.tight_layout(h_pad = 0.5, w_pad = 0.5, pad = 2.5)
    
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap = plt.cm.RdYlBu)
    
    plt.xlabel(iris.feature_names[pair[0]])
    plt.ylabel(iris.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y == i)
        plt.scatter(X[idx, 0], X[idx, 1], c = color, label = iris.target_names[i],
                   cmap = plt.cm.RdYlBu, edgecolors = 'b', s = 15)

plt.suptitle("Decision surface")
plt.legend(loc = 'lower right', borderpad = 0, handletextpad=0)
plt.axis('tight');

# %% [markdown]
# ### 하이퍼파라미터를 변경해 보면서 결정 경계의 변화 확인

# %%
plt.figure(figsize = (16, 8))

for pairidx, pair in enumerate([[0, 1],[0, 2], [0, 3],
                                [1, 2], [1, 3], [2, 3]]):
    X = iris.data[:, pair]
    y = iris.target
    
    model = DecisionTreeClassifier(max_depth = 2) # 과적합을 방지하기위해 적절한 깊이를 정해주는게 좋음
    model = model.fit(X, y)
    
    plt.subplot(2, 3, pairidx + 1) # 결정 경계 시각화를 위해 작성 / 서브 플롯마다 어떤 경계를 나타내는지가 결국 트리 형성의 기준이 됨
    
    x_min, x_max = X[:, 0].min()-1, X[:, 0].max()+1
    y_min, y_max = X[:, 1].min()-1, X[:, 1].max()+1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                         np.arange(y_min, y_max, plot_step))
    
    plt.tight_layout(h_pad = 0.5, w_pad = 0.5, pad = 2.5)
    
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap = plt.cm.RdYlBu)
    
    plt.xlabel(iris.feature_names[pair[0]])
    plt.ylabel(iris.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y == i)
        plt.scatter(X[idx, 0], X[idx, 1], c = color, label = iris.target_names[i],
                   cmap = plt.cm.RdYlBu, edgecolors = 'b', s = 15)

plt.suptitle("Decision surface")
plt.legend(loc = 'lower right', borderpad = 0, handletextpad=0)
plt.axis('tight');

# %% [markdown]
# ## 와인 데이터 학습

# %% [markdown]
# ### 전처리 없이 학습

# %%
model = DecisionTreeClassifier()

# %%
cross_val_score(
    estimator = model,
    X = wine.data, y = wine.target,
    cv = 5,
    n_jobs = multiprocessing.cpu_count()
)
# Out:
# array([0.94444444, 0.77777778, 0.91666667, 0.91428571, 0.82857143])

# %% [markdown]
# ### 전처리 후 학습

# %%
model = make_pipeline(
        StandardScaler(),
        DecisionTreeClassifier()
)

# %%
cross_val_score(
    estimator = model,
    X = wine.data, y = wine.target,
    cv = 5,
    n_jobs = multiprocessing.cpu_count()
)
# Out:
# array([0.91666667, 0.86111111, 0.83333333, 0.91428571, 0.85714286])

# %% [markdown]
# #### 이후 과정은 위 데이터와 동일하므로 생략

# %% [markdown]
# # 회귀 - DecisionTreeRegressor()
# - X는 [n_samples, n_features] 크기의 데이터 특성 배열
# - y는 [n_samples] 크기의 정답 배열

# %% [markdown]
# ## 보스턴 주택 가격 데이터 학습

# %% [markdown]
# ### 전처리 없이 학습

# %%
model = DecisionTreeRegressor()

# %%
cross_val_score(
        estimator = model,
        X = boston.data, y = boston.target,
        cv = 5,
        n_jobs = multiprocessing.cpu_count()
)
# Out:
# array([ 0.63507532,  0.68575416,  0.59843277,  0.36966081, -1.53483254])

# %% [markdown]
# ### 전처리 후 학습

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeRegressor()
)

# %%
cross_val_score(
    estimator = model,
    X = boston.data, y = boston.target,
    cv = 5,
    n_jobs = multiprocessing.cpu_count()
)
# Out:
# array([ 0.6018015 ,  0.63678797,  0.57851636,  0.40592604, -1.77329058])

# %% [markdown]
# ## 당뇨병 데이터 학습

# %% [markdown]
# ### 전처리 없이 학습

# %%
model = DecisionTreeRegressor()

# %%
cross_val_score(
        estimator = model,
        X = diabetes.data, y = diabetes.target,
        cv = 5,
        n_jobs = multiprocessing.cpu_count()
)
# Out:
# array([-0.30119053, -0.09071465, -0.1185963 , -0.0772701 , -0.1719277 ])

# %% [markdown]
# ### 전처리 후 학습

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeRegressor()
)

# %%
cross_val_score(
    estimator = model,
    X = diabetes.data, y = diabetes.target,
    cv = 5,
    n_jobs = multiprocessing.cpu_count()
)
# Out:
# array([-0.38259319, -0.12766113, -0.23588611, -0.0127827 , -0.13360466])
